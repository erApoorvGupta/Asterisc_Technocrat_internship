# %% [markdown]
# <div align="center">
#
# # 🌟TASK 2
#
# ## [Apoorv Gupta](https://www.linkedin.com/in/er-apoorv-gupta/)
# ### 🧠 Data Science Intern @ Astric Technocrats
#
#
# </div>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Information about the Dataset

# %%
# loading dataset
df = pd.read_csv('Stock_price_prediction.csv')
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 0    2020-01-27  71.320000  71.635002  71.320000  71.324997  71.324997       0
# 1    2020-01-28  71.654999  71.654999  71.178001  71.440002  71.440002       0
# 2    2020-01-29  71.230103  71.425003  71.168503  71.230400  71.230400       0
# 3    2020-01-30  71.300003  71.711998  71.300003  71.300003  71.300003       0
# 4    2020-01-31  71.639999  71.639999  71.277496  71.639999  71.639999       0
# ..          ...        ...        ...        ...        ...        ...     ...
# 257  2021-01-20  73.192001  73.192299  72.899300  73.191902  73.191902       0
# 258  2021-01-21  72.907898  73.045303  72.883003  72.910896  72.910896       0
# 259  2021-01-22  72.954903  73.237503  72.929001  72.954903  72.954903       0
# 260  2021-01-25  72.995903  73.220001  72.877998  72.995903  72.995903       0
# 261  2021-01-26  72.970001  73.222000  72.774498  72.970001  72.970001       0
#
# [262 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       262 non-null    object
#  1   Open       262 non-null    float64
#  2   High       262 non-null    float64
#  3   Low        262 non-null    float64
#  4   Close      262 non-null    float64
#  5   Adj Close  262 non-null    float64
#  6   Volume     262 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.5+ KB

# %% [markdown]
# ### There is no missing data.. The data is clean as we can see below

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Removing Date coloumn as they are not required for prediction.
# ##### This information was known through domain Knowledge

# %%
# rmoving Date coloumn
df.drop('Date', axis=1, inplace=True)
df
# Out:
#           Open       High        Low      Close  Adj Close  Volume
# 0    71.320000  71.635002  71.320000  71.324997  71.324997       0
# 1    71.654999  71.654999  71.178001  71.440002  71.440002       0
# 2    71.230103  71.425003  71.168503  71.230400  71.230400       0
# 3    71.300003  71.711998  71.300003  71.300003  71.300003       0
# 4    71.639999  71.639999  71.277496  71.639999  71.639999       0
# ..         ...        ...        ...        ...        ...     ...
# 257  73.192001  73.192299  72.899300  73.191902  73.191902       0
# 258  72.907898  73.045303  72.883003  72.910896  72.910896       0
# 259  72.954903  73.237503  72.929001  72.954903  72.954903       0
# 260  72.995903  73.220001  72.877998  72.995903  72.995903       0
# 261  72.970001  73.222000  72.774498  72.970001  72.970001       0
#
# [262 rows x 6 columns]

# %% [markdown]
# ### Checking value of "volume" coloumn

# %%
# checking value of volume coloumn
df['Volume'].value_counts()
# Out:
# 0    262
# Name: Volume, dtype: int64

# %% [markdown]
# <br>
#
# ### As we can all values in volume coloumn are same, so we can remove this coloumn as it will not help in prediction

# %%
# removing volume coloumn
df.drop('Volume', axis=1, inplace=True)
df
# Out:
#           Open       High        Low      Close  Adj Close
# 0    71.320000  71.635002  71.320000  71.324997  71.324997
# 1    71.654999  71.654999  71.178001  71.440002  71.440002
# 2    71.230103  71.425003  71.168503  71.230400  71.230400
# 3    71.300003  71.711998  71.300003  71.300003  71.300003
# 4    71.639999  71.639999  71.277496  71.639999  71.639999
# ..         ...        ...        ...        ...        ...
# 257  73.192001  73.192299  72.899300  73.191902  73.191902
# 258  72.907898  73.045303  72.883003  72.910896  72.910896
# 259  72.954903  73.237503  72.929001  72.954903  72.954903
# 260  72.995903  73.220001  72.877998  72.995903  72.995903
# 261  72.970001  73.222000  72.774498  72.970001  72.970001
#
# [262 rows x 5 columns]

# %% [markdown]
# ### We also found that the value in "CLose" coloumn and "Adj Close" coloumn are same, so we can remove one of them.. I am choosing "Close" coloumn to remove.

# %%
comparison_result = df["Close"] == df["Adj Close"]
count_result = comparison_result.value_counts()

if True in count_result:
    true_count = count_result[True]
else:
    true_count = 0

if False in count_result:
    false_count = count_result[False]
else:
    false_count = 0

print("True count:", true_count)
print("False count:", false_count)
# Out:
# True count: 262
# False count: 0

# %%
# dropping Close coloumn
df.drop('Close', axis=1, inplace=True)
df
# Out:
#           Open       High        Low  Adj Close
# 0    71.320000  71.635002  71.320000  71.324997
# 1    71.654999  71.654999  71.178001  71.440002
# 2    71.230103  71.425003  71.168503  71.230400
# 3    71.300003  71.711998  71.300003  71.300003
# 4    71.639999  71.639999  71.277496  71.639999
# ..         ...        ...        ...        ...
# 257  73.192001  73.192299  72.899300  73.191902
# 258  72.907898  73.045303  72.883003  72.910896
# 259  72.954903  73.237503  72.929001  72.954903
# 260  72.995903  73.220001  72.877998  72.995903
# 261  72.970001  73.222000  72.774498  72.970001
#
# [262 rows x 4 columns]

# %% [markdown]
# <br>
#
# ### We test if the data need to be scaled or not through a test of skewness

# %%
df.skew()
# Out:
# Open        -0.278198
# High        -0.110197
# Low         -0.378185
# Adj Close   -0.242576
# dtype: float64

# %% [markdown]
# The data is not skewed so we do not need to scale the data

# %% [markdown]
# <br>
#
# ### Displaying the data after cleaning for visualization

# %%
# Original dataframe without close and volume coloumn

df1 = pd.read_csv('Stock_price_prediction.csv')
df1.drop(['Close','Volume'], axis=1, inplace=True)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create subplots with 2 rows and 2 columns
fig = make_subplots(rows=2, cols=2, subplot_titles=['<b>Open vs Date</b>', '<b>High vs Date</b>', '<b>Low vs Date</b>', '<b>Adj Close vs Date</b>'])

# Add traces for each subplot
fig.add_trace(go.Scatter(x=df1['Date'], y=df1['Open'], name='Open'), row=1, col=1)
fig.add_trace(go.Scatter(x=df1['Date'], y=df1['High'], name='High'), row=1, col=2)
fig.add_trace(go.Scatter(x=df1['Date'], y=df1['Low'], name='Low'), row=2, col=1)
fig.add_trace(go.Scatter(x=df1['Date'], y=df1['Adj Close'], name='Adj Close'), row=2, col=2)

# Update subplot titles
fig.update_xaxes(title_text='Date', row=1, col=1)
fig.update_xaxes(title_text='Date', row=1, col=2)
fig.update_xaxes(title_text='Date', row=2, col=1)
fig.update_xaxes(title_text='Date', row=2, col=2)

# Update y-axis titles
fig.update_yaxes(title_text='Open', row=1, col=1)
fig.update_yaxes(title_text='High', row=1, col=2)
fig.update_yaxes(title_text='Low', row=2, col=1)
fig.update_yaxes(title_text='Adj Close', row=2, col=2)

# Set the figure layout
fig.update_layout(
    title_text='<b>Stock Price Analysis</b>',
    title_font=dict(size=24, color='purple'),
    font=dict(size=12, color='black'),
    height=600,
    width=900,
    showlegend=False,
)

fig.show()

# %% [markdown]
# <br><br>
#
# ## Moving on to the Prediction part

# %% [markdown]
# <br><br><div align="center">
#
# # <span style="color: purple; font-size: 56px; font-weight: bold;">LSTM Networks for Stock Prediction</span>
#
# </div>
#
# ![LSTM Network](https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/LSTM_Cell.svg/1200px-LSTM_Cell.svg.png)
#
#
# #### LSTM networks have gained popularity in stock prediction tasks due to their ability to capture long-term dependencies and handle sequential data effectively. Stock prices are inherently sequential, where each data point depends on previous data points and exhibits temporal patterns. Traditional machine learning models struggle to capture these complex patterns, leading to suboptimal predictions.
#
# #### LSTM networks excel at modeling and predicting time series data, making them a natural choice for stock prediction. Their memory cell allows them to remember important historical information, such as past stock prices, trends, and market conditions. By learning from this historical context, LSTM networks can identify and exploit patterns in the data that may affect future stock prices.
#
# #### Furthermore, LSTM networks can handle noisy and non-linear data, which are common characteristics of stock market data. They can adapt and update their internal state based on new information, enabling them to adapt to changing market dynamics. This adaptability is crucial for accurate stock price predictions, as market conditions and trends evolve over time.
#
# #### Another advantage of LSTM networks is their ability to incorporate various input features. In addition to historical stock prices, other relevant factors such as trading volume, technical indicators, news sentiment, and economic data can be included as input to the network. This flexibility allows LSTM networks to capture multiple dimensions of information and potentially improve the prediction accuracy.

# %%
# Applying LSTM model for stock price prediction
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Extract the 'Adj Close' column as the target variable
target_variable = 'Adj Close'
target_data = df[target_variable].values

# Split the data into training and testing sets (80% train, 20% test)
train_size = int(len(df) * 0.8)
train_data = target_data[:train_size]
test_data = target_data[train_size:]

# Normalize the data to a range between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
train_data_normalized = scaler.fit_transform(train_data.reshape(-1, 1))
test_data_normalized = scaler.transform(test_data.reshape(-1, 1))

# Reshape the data into the input shape required by LSTM models (samples, time steps, features)
def create_sequences(data, time_steps):
    X = []
    y = []
    for i in range(len(data) - time_steps):
        X.append(data[i : i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 2  # Adjust this value as per your requirement
X_train, y_train = create_sequences(train_data_normalized, time_steps)
X_test, y_test = create_sequences(test_data_normalized, time_steps)

# Build the LSTM model architecture
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(time_steps, 1), return_sequences=True))
model.add(LSTM(units=50, activation='relu', return_sequences=True))
model.add(LSTM(units=50, activation='relu', return_sequences=True))
model.add(LSTM(units=50, activation='relu'))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model on the training data
model.fit(X_train, y_train, epochs=500, batch_size=32)

# Evaluate the model on the testing data
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')

# Make predictions using the trained model
predicted_data_normalized = model.predict(X_test)
predicted_data = scaler.inverse_transform(predicted_data_normalized)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 3s 3ms/step - loss: 0.3320
# Epoch 2/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3061
# Epoch 3/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2748
# Epoch 4/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2364
# Epoch 5/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1875
# Epoch 6/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1287
# Epoch 7/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0642
# Epoch 8/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0444
# Epoch 9/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0466
# Epoch 10/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0379
# Epoch 11/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0378
# Epoch 12/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0326
# ...

# %%
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_70 (LSTM)              (None, 2, 50)             10400
#
#  lstm_71 (LSTM)              (None, 2, 50)             20200
#
#  lstm_72 (LSTM)              (None, 2, 50)             20200
#
#  lstm_73 (LSTM)              (None, 50)                20200
#
#  dense_22 (Dense)            (None, 1)                 51
#
# ...
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Evaluation Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate the predictions
predicted_data_normalized = model.predict(X_test)
predicted_data = scaler.inverse_transform(predicted_data_normalized)

# Calculate the evaluation metrics
mse = mean_squared_error(y_test, predicted_data)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predicted_data)
r2 = r2_score(y_test, predicted_data)

# Print the evaluation metrics
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R^2) Score: {r2}')
# Out:
# 2/2 [==============================] - 0s 3ms/step
# Mean Squared Error (MSE): 5393.065696827733
# Root Mean Squared Error (RMSE): 73.43749516989078
# Mean Absolute Error (MAE): 73.43698661042627
# R-squared (R^2) Score: -1314805.2059234506

# %%
# Get the predicted values for the training dataset
predicted_train_normalized = model.predict(X_train)
predicted_train = scaler.inverse_transform(predicted_train_normalized)

# Get the predicted values for the test dataset
predicted_test_normalized = model.predict(X_test)
predicted_test = scaler.inverse_transform(predicted_test_normalized)

# Plot the predicted and real values for the training dataset
plt.figure(figsize=(15, 5))
plt.plot(predicted_train, label='Predicted (Train)', color='blue')
plt.plot(target_data[:len(X_train)], label='Real (Train)', color='green')

# Plot the predicted and real values for the test dataset
test_range = range(len(X_train), len(X_train) + len(predicted_test))
plt.plot(test_range[:len(predicted_test)], predicted_test, label='Predicted (Test)', color='red')
plt.plot(test_range[:len(predicted_test)], target_data[-len(predicted_test):], label='Real (Test)', color='orange')

plt.xlabel('Time', fontsize=14, fontweight='bold')
plt.ylabel('Adj Close', fontsize=14, fontweight='bold')
plt.title('Predicted vs Real Stock Prices', fontsize=24, fontweight='bold',color='purple')
plt.legend()

# Add grid lines
plt.grid(True, which='both', linestyle='-', linewidth=0.5)

# Customize tick labels
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(8))
plt.gca().yaxis.set_major_locator(plt.MaxNLocator(5))

legend = plt.legend(frameon=True, shadow=True)

for line in legend.get_lines():
    line.set_linewidth(1.5)

plt.tight_layout()
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 4ms/step

# %% [markdown]
# #### <b> The graph compares the predicted and real stock prices over time. The blue line represents the predicted prices for the training dataset, while the green line represents the actual prices for the training dataset. The red line shows the predicted prices for the test dataset, plotted against the actual prices (shown in orange) for the test dataset. The x-axis represents time, and the y-axis represents the adjusted closing prices of the stocks. This graph provides an overview of how well the LSTM model captures the underlying patterns and trends in the data.

# %% [markdown]
# <div align="center">
#
# ## -- End of Task 2 --
# </div>
